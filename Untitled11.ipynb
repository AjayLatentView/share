# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils import resample
from sklearn import preprocessing

from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,IsolationForest
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC


from sklearn.metrics import accuracy_score,confusion_matrix,r2_score,mean_squared_error,mean_absolute_error,precision_score,recall_score,f1_score,roc_auc_score

# %%
class pred_analysis:
  def __init__(self):
    pass

  def details(self,df,target):                         #No return
    print("shape=",df.shape)
    print("\n")
    print("duplicates=")
    print(df[df.duplicated()].count())
    print("\n")
    print("Nulls=")
    print(df.isnull().sum())
    print("\n")
    print("balance=")
    print(df[target].value_counts())

  def balance(self,df,target):
    df1=df[df[target]==0]
    df2=df[df[target]==1]
    mini=min(df[target].value_counts().values)
    maxi=max(df[target].value_counts().values)
    if len(df1)>len(df2):
      df1_new=resample(df1,random_state=42,replace=True,n_samples=mini)
      df=pd.concat([df1_new,df2])
    else:
      df2_new=resample(df1,random_state=42,replace=True,n_samples=mini)
      df=pd.concat([df1,df2_new])
    return df

  def preprocess(self,df,bin,target):
    if "Unnamed: 0" in df.columns:
      df=df.drop("Unnamed: 0",axis=1)
    df.drop_duplicates(inplace=True)
    if bin==True:
      df=balance(df,target)
    df.fillna(method="ffill",inplace=True)
    return df


  def remove_outliers(self,df,i):
    q1=df[i].quantile(0.25)
    q3=df[i].quantile(0.75)

    iqr=q3-q1
    med=df[i].median()
    df=np.where((df[i]<q1-(1.5*iqr)) | (df[i]>q3+(1.5*iqr)),med,df[i])
    return df

  def encoder(self,df,lst):                                 #  No return
    for i in lst:
      df[i]=preprocessing.LabelEncoder().fit_transform(df[i])

  def data_split(df,target,size):
    X=df.drop(columns=[target])
    y=df[target]
    x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=size,random_state=42)
    print(f'Records in dataset: {df.shape[0]}')
    print(f'Records in train dataset: {x_train.shape[0]}')
    print(f'Records in test dataset: {x_test.shape[0]}')
    return (x_train,x_test,y_train,y_test)

  def metrics(self,y_test,res):
    print(f"Accuracy score={accuracy_score(y_test,res)*100}")
    print(f"precision={precision_score(y_test,res)}")
    print(f"Recall={recall_score(y_test,res)*100}")
    print(f"F1 score={f1_score(y_test,res)*100}")
    print(f"Confusion Matrix=")
    conf_matrix=confusion_matrix(y_test,res)
    sns.heatmap(conf_matrix,annot=True)
    plt.show()

  def model_execute(self,models,x_train,x_test,y_train,y_test):
    for mod in models:
      clf=models[mod]
      clf.fit(x_train,y_train)
      res=clf.predict(x_test)
      print(f"{clf}")
      print("\n")
      metrics(y_test,res)

# %%
obj=pred_analysis()

# %%
df=pd.read_csv("/content/student_performance_uncleaned.csv")
df.head()
# Out:
#   school sex  age  traveltime  studytime  failures pass
# 0     MS   M   17           2          4         0  yes
# 1     GP   M   20           2          2         1  yes
# 2     GP   M   -1           4          2         2   no
# 3     GP   F   13           3          1         2   no
# 4     MS   F   16           3          1         3  yes

# %%
target="pass"
obj.details(df,target)
# Out:
# shape= (1000000, 7)
#
#
# duplicates=
# school        965846
# sex           965747
# age           981676
# traveltime    981676
# studytime     981676
# failures      981676
# pass          965742
# dtype: int64
#
#
# Nulls=
# school        19855
# sex           19990
# age               0
# traveltime        0
# studytime         0
# failures          0
# pass          19977
# dtype: int64
#
#
# balance=
# yes    499735
# no     480288
# Name: pass, dtype: int64

# %%
df=obj.preprocess(df,True,target)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-0948e3d111e4> in <cell line: 1>()
# ----> 1 df=obj.preprocess(df,True,target)
#
# <ipython-input-14-a77e8d3a31fc> in preprocess(self, df, bin, target)
#      33     df.drop_duplicates(inplace=True)
#      34     if bin==True:
# ---> 35       df=balance(df,target)
#      36     df.fillna(method="ffill",inplace=True)
#      37     return df
#
# NameError: name 'balance' is not defined

# %%
details
