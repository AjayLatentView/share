# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.utils import resample

from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier


from sklearn.metrics import accuracy_score,confusion_matrix,r2_score,mean_squared_error,mean_absolute_error,precision_score,recall_score,f1_score,roc_auc_score

# %%
def remove_outliers(df,i):
    q1=df[i].quantile(0.25)
    q3=df[i].quantile(0.75)

    iqr=q3-q1
    med=df[i].median()
    df=np.where((df[i]<q1-(1.5*iqr)) | (df[i]>q3+(1.5*iqr)),med,df[i])
    return df

# %%
def balance(df,target):
  df1=df[df[target]==0]
  df2=df[df[target]==1]
  mini=min(df[target].value_counts().values)
  maxi=max(df[target].value_counts().values)
  if len(df1)>len(df2):
    df1_new=resample(df1,random_state=42,replace=True,n_samples=mini)
    df=pd.concat([df1_new,df2])
  else:
    df2_new=resample(df1,random_state=42,replace=True,n_samples=mini)
    df=pd.concat([df1,df2_new])
  return df

# %%
def preprocess(df,bin,target):
  df.drop_duplicates(inplace=True)
  if bin==True:
    df=balance(df,target)
    print(df.Churn.value_counts())
  df.fillna(method="ffill",inplace=True)
  return df

# %%
def encoder(df,lst):
  for i in lst:
    df[i]=preprocessing.LabelEncoder().fit_transform(df[i])

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Deepsphere-AI/DataAnalyticsTraining/main/PredictiveAnalytics/Telco-Customer-Churn.csv")
x="Churn"
df=preprocess(df,True,x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-c6ed88ef7150> in <cell line: 3>()
#       1 df=pd.read_csv("https://raw.githubusercontent.com/Deepsphere-AI/DataAnalyticsTraining/main/PredictiveAnalytics/Telco-Customer-Churn.csv")
#       2 x="Churn"
# ----> 3 df=preprocess(df,True,x)
#
# <ipython-input-23-a029c2814516> in preprocess(df, bin, target)
#       2   df.drop_duplicates(inplace=True)
#       3   if bin==True:
# ----> 4     df=balance(df,target)
#       5     print(df.Churn.value_counts())
#       6   df.fillna(method="ffill",inplace=True)
#
# <ipython-input-3-baf0e664b253> in balance(df, target)
#       8     df=pd.concat([df1_new,df2])
#       9   else:
# ---> 10     df2_new=resample(df1,random_state=42,replace=True,n_samples=mini)
#      11     df=pd.concat([df1,df2_new])
#      12   return df
#
# ...

# %%
num=df.columns[df.dtypes!=object]
cat=df.columns[df.dtypes==object]
encoder(df,cat)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0        5375       0              0        1           0       1
# 1        3962       1              0        0           0      34
# 2        2564       1              0        0           0       2
# 3        5535       1              0        0           0      45
# 4        6511       0              0        0           0       2
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0             0              1                0               0  ...
# 1             1              0                0               2  ...
# 2             1              0                0               2  ...
# 3             0              1                0               2  ...
# 4             1              0                1               0  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
df.Churn.value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64
